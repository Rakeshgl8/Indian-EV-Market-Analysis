# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %% [markdown]
# # 1.Indian EV Market Analysis 2010-2023

# %%
# Load the dataset
df0=pd.read_csv('Final Datasets/IEA Global EV Data 2024.csv')

# %%
# Glimpse of data
print("Columns in the dataset:\n")
print(df0.columns)
print("\nFirst few rows of the dataset:")
print(df0.head())
# Out:
# Columns in the dataset:
#
# Index(['region', 'category', 'parameter', 'mode', 'powertrain', 'year', 'unit',
#        'value'],
#       dtype='object')
#
# First few rows of the dataset:
#       region    category       parameter  mode powertrain  year      unit  \
# 0  Australia  Historical  EV stock share  Cars         EV  2011   percent
# 1  Australia  Historical  EV sales share  Cars         EV  2011   percent
# 2  Australia  Historical        EV sales  Cars        BEV  2011  Vehicles
# 3  Australia  Historical        EV stock  Cars        BEV  2011  Vehicles
# 4  Australia  Historical        EV stock  Cars        BEV  2012  Vehicles
#
#        value
# 0    0.00039
# 1    0.00650
# 2   49.00000
# 3   49.00000
# 4  220.00000

# %%
# Unique values of each columns
for col in df0.columns:
    unique_values=df0[col].unique()
    print(f"Unique values in column '{col}': {unique_values}\n")
# Out:
# Unique values in column 'region': ['Australia' 'Austria' 'Belgium' 'Brazil' 'Bulgaria' 'Canada' 'Chile'
#  'China' 'Colombia' 'Costa Rica' 'Croatia' 'Cyprus' 'Czech Republic'
#  'Denmark' 'Estonia' 'EU27' 'Europe' 'Finland' 'France' 'Germany' 'Greece'
#  'Hungary' 'Iceland' 'India' 'Indonesia' 'Ireland' 'Israel' 'Italy'
#  'Japan' 'Korea' 'Latvia' 'Lithuania' 'Luxembourg' 'Mexico' 'Netherlands'
#  'New Zealand' 'Norway' 'Poland' 'Portugal' 'Rest of the world' 'Romania'
#  'Seychelles' 'Slovakia' 'Slovenia' 'South Africa' 'Spain' 'Sweden'
#  'Switzerland' 'Thailand' 'Turkiye' 'United Arab Emirates'
#  'United Kingdom' 'USA' 'World']
#
# Unique values in column 'category': ['Historical' 'Projection-STEPS' 'Projection-APS']
#
# Unique values in column 'parameter': ['EV stock share' 'EV sales share' 'EV sales' 'EV stock'
#  'EV charging points' 'Electricity demand' 'Oil displacement Mbd'
#  'Oil displacement, million lge']
#
# Unique values in column 'mode': ['Cars' 'EV' 'Buses' 'Vans' 'Trucks']
#
# Unique values in column 'powertrain': ['EV' 'BEV' 'PHEV' 'Publicly available fast' 'Publicly available slow'
#  'FCEV']
#
# Unique values in column 'year': [2011 2012 2013 2014 2015 2016 2017 2018 2019 2020 2021 2022 2023 2010
#  2025 2030 2035]
#
# Unique values in column 'unit': ['percent' 'Vehicles' 'charging points' 'GWh' 'Milion barrels per day'
#  'Oil displacement, million lge']
#
# Unique values in column 'value': [3.90000001e-04 6.50000013e-03 4.90000000e+01 ... 9.40000000e+05
#  3.90000000e+08 9.40000000e+06]

# %%
# Filtering the data
df_Indian =df0[(df0['region'] == 'India')&
            (df0['category'] == 'Historical')&
            (df0['mode'] == 'Cars')&
            (df0['powertrain'].isin(['EV', 'BEV', 'PHEV']))].reset_index(drop=True)

# %%
df_Indian.columns
# Out:
# Index(['region', 'category', 'parameter', 'mode', 'powertrain', 'year', 'unit',
#        'value'],
#       dtype='object')

# %%
df_Indian.head()
# Out:
#   region    category             parameter  mode powertrain  year  \
# 0  India  Historical              EV sales  Cars        BEV  2010
# 1  India  Historical              EV stock  Cars        BEV  2010
# 2  India  Historical        EV sales share  Cars         EV  2010
# 3  India  Historical        EV stock share  Cars         EV  2010
# 4  India  Historical  Oil displacement Mbd  Cars         EV  2010
#
#                      unit       value
# 0                Vehicles  450.000000
# 1                Vehicles  880.000000
# 2                 percent    0.021000
# 3                 percent    0.005000
# 4  Milion barrels per day    0.000022

# %%
for col in df_Indian.columns:
    unique_values=df_Indian[col].unique()
    print(f"Unique values in column '{col}': {unique_values}\n")
# Out:
# Unique values in column 'region': ['India']
#
# Unique values in column 'category': ['Historical']
#
# Unique values in column 'parameter': ['EV sales' 'EV stock' 'EV sales share' 'EV stock share'
#  'Oil displacement Mbd' 'Oil displacement, million lge'
#  'Electricity demand']
#
# Unique values in column 'mode': ['Cars']
#
# Unique values in column 'powertrain': ['BEV' 'EV' 'PHEV']
#
# Unique values in column 'year': [2010 2011 2012 2013 2014 2015 2016 2017 2018 2019 2020 2021 2022 2023]
#
# Unique values in column 'unit': ['Vehicles' 'percent' 'Milion barrels per day'
#  'Oil displacement, million lge' 'GWh']
#
# Unique values in column 'value': [4.50000000e+02 8.80000000e+02 2.09999997e-02 4.99999989e-03
#  2.20000002e-05 1.29999995e+00 4.50000007e-05 2.59999990e+00
#  6.69999979e-03 5.60000017e-02 1.30000000e+03 1.40000000e+03
#  1.90000000e+02 2.80000000e+03 7.19999988e-03 1.20000001e-02
#  4.99999987e-05 2.90000010e+00 1.60000008e-02 2.90000000e+03
#  4.10000000e+02 1.00000000e+03 3.40000000e+03 3.79999988e-02
#  1.30000003e-02 6.50000002e-05 3.70000005e+00 7.40000032e-05
#  4.19999981e+00 1.49999997e-02 1.70000009e-02 4.40000000e+03
#  7.30000000e+02 4.80000000e+03 2.60000005e-02 8.39999993e-05
#  4.80000019e+00 9.99999975e-05 5.80000019e+00 3.09999995e-02
#  7.00000000e+03 9.20000000e+02 7.90000000e+03 2.99999993e-02
#  2.19999999e-02 1.10000001e-04 6.59999990e+00 3.89999989e-03
#  1.19999997e-04 7.00000000e+00 2.40000002e-02 8.60000000e+03
#  6.80000000e+02 5.00000000e+01 4.30000000e+01 3.10000000e+03
#  1.20000000e+04 1.19999997e-01 2.89999992e-02 1.50000007e-04
#  8.50000000e+00 2.30000000e-02 5.29999994e-02 3.49999988e-04
#  2.00000000e+01 5.40000014e-02 3.49999994e-01 2.30000000e+04
#  1.00000000e+02 1.20000000e+02 2.30000000e+01 4.80000000e+04
#  7.20000000e+04 1.20000005e+00 1.50000006e-01 1.30000000e-03
#  7.20000000e+01 7.40000010e-02 2.60000001e-03 1.50000000e+02
#  3.10000002e-01 2.00000000e+00 1.50000000e+05 8.20000000e+04
#  2.70000000e+02 3.90000000e+02]

# %%
df_Indian.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   region      99 non-null     object
#  1   category    99 non-null     object
#  2   parameter   99 non-null     object
#  3   mode        99 non-null     object
#  4   powertrain  99 non-null     object
#  5   year        99 non-null     int64
#  6   unit        99 non-null     object
#  7   value       99 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 6.3+ KB

# %%
df_Indian1 = df_Indian[['parameter', 'powertrain', 
               'year', 'unit', 'value']]
df_Indian1
# Out:
#                parameter powertrain  year                    unit  \
# 0               EV sales        BEV  2010                Vehicles
# 1               EV stock        BEV  2010                Vehicles
# 2         EV sales share         EV  2010                 percent
# 3         EV stock share         EV  2010                 percent
# 4   Oil displacement Mbd         EV  2010  Milion barrels per day
# ..                   ...        ...   ...                     ...
# 94        EV sales share         EV  2023                 percent
# 95              EV stock        BEV  2023                Vehicles
# 96              EV sales        BEV  2023                Vehicles
# 97              EV sales       PHEV  2023                Vehicles
# 98              EV stock       PHEV  2023                Vehicles
#
#             value
# 0      450.000000
# 1      880.000000
# 2        0.021000
# 3        0.005000
# 4        0.000022
# ..            ...
# 94       2.000000
# 95  150000.000000
# 96   82000.000000
# 97     270.000000
# 98     390.000000
#
# [99 rows x 5 columns]

# %%
df_Indian2 = df_Indian1[['parameter', 'year', 'value']].groupby(['parameter', 'year']).sum()
df_Indian2
# Out:
#                                      value
# parameter                     year
# EV sales                      2010   450.0
#                               2011  1400.0
#                               2012   190.0
#                               2013   410.0
#                               2014  1000.0
# ...                                    ...
# Oil displacement, million lge 2019     7.0
#                               2020     8.5
#                               2021    20.0
#                               2022    72.0
#                               2023   150.0
#
# [89 rows x 1 columns]

# %%
df_Indian1.parameter.unique()
# Out:
# array(['EV sales', 'EV stock', 'EV sales share', 'EV stock share',
#        'Oil displacement Mbd', 'Oil displacement, million lge',
#        'Electricity demand'], dtype=object)

# %%
df_Indian2.loc['EV sales share']
# Out:
#        value
# year
# 2010  0.0210
# 2011  0.0560
# 2012  0.0072
# 2013  0.0160
# 2014  0.0380
# 2015  0.0170
# 2016  0.0260
# 2017  0.0310
# 2018  0.0300
# 2019  0.0240
# 2020  0.1200
# 2021  0.3500
# 2022  1.2000
# 2023  2.0000

# %%
fig, axs = plt.subplots(4, 2, figsize=(30, 30))
axs = axs.flatten()
parameters = df_Indian1.parameter.unique()
for ax, parameter in zip(axs, parameters):
    temp = df_Indian2.loc[parameter]
    ax.plot(temp.index, temp.value, '-o')
    ax.set_title(parameter)
    ax.set_xlabel('year')
    ax.set_ylabel('value')
plt.suptitle('EV Sales Historical Cars parameters')
#plt.savefig('EV Sales Historical Cars parameters.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
df_Indian3 = df_Indian1[['powertrain', 'year', 'value']].groupby(['powertrain', 'year']).sum()
df_Indian3
# Out:
#                          value
# powertrain year
# BEV        2010    1330.000000
#            2011    2700.000000
#            2012    2990.000000
#            2013    3310.000000
#            2014    4400.000000
#            2015    4850.000000
#            2016    5530.000000
#            2017    7920.000000
#            2018    8820.000000
#            2019    9280.000000
#            2020   15100.000000
#            2021   35000.000000
#            2022  120000.000000
#            2023  232000.000000
# EV         2010       1.326022
#            2011       2.662745
#            2012       2.619245
#            2013       2.928050
#            2014       3.751065
#            2015       4.232074
#            2016       4.841084
#            2017       5.852100
#            2018       6.652110
#            2019       7.050020
#            2020       8.672150
#            2021      20.457350
#            2022      73.425300
#            2023     562.312600
# PHEV       2019      14.000000
#            2020      93.000000
#            2021     150.000000
#            2022     143.000000
#            2023     660.000000

# %%
df_Indian1.powertrain.unique()
# Out:
# array(['BEV', 'EV', 'PHEV'], dtype=object)

# %%
fig, axs = plt.subplots(2, 2, figsize=(20, 15))
axs = axs.flatten()
powertrains = df_Indian1.powertrain.unique()
for ax, powertrain in zip(axs, powertrains):
    temp = df_Indian3.loc[powertrain]
    ax.plot(temp.index, temp.value, '-o')
    ax.set_title(powertrain)
    ax.set_xlabel('year')
    ax.set_ylabel('value')
plt.suptitle('EV Sales Historical Cars powertrain')
plt.savefig('EV Sales Historical Cars powertrain.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### PCA

# %%
df_Indian1.head()
# Out:
#               parameter powertrain  year                    unit       value
# 0              EV sales        BEV  2010                Vehicles  450.000000
# 1              EV stock        BEV  2010                Vehicles  880.000000
# 2        EV sales share         EV  2010                 percent    0.021000
# 3        EV stock share         EV  2010                 percent    0.005000
# 4  Oil displacement Mbd         EV  2010  Milion barrels per day    0.000022

# %%
df_Indian4 = df_Indian1.copy()  

label_encoders = [LabelEncoder() for _ in range(5)]

for le, column in zip(label_encoders, df_Indian4.columns):
    df_Indian4.loc[:, column] = le.fit_transform(df_Indian4[column])

standard_scaler = StandardScaler()

df_Indian4_scaled = standard_scaler.fit_transform(df_Indian4)

df_Indian4_scaled = pd.DataFrame(df_Indian4_scaled, columns=df_Indian4.columns)

df_Indian4_scaled[:5]
# Out:
#    parameter  powertrain      year      unit     value
# 0  -1.307302   -1.381440 -1.757727  0.251311  0.836329
# 1  -0.341459   -1.381440 -1.757727  0.251311  0.958447
# 2  -0.824380    0.306987 -1.757727  1.109234 -0.832628
# 3   0.141462    0.306987 -1.757727  1.109234 -1.158278
# 4   1.107304    0.306987 -1.757727 -1.464535 -1.728166

# %%
pca = PCA(n_components=5)
df_Indian4_scaled_pca = pca.fit_transform(df_Indian4_scaled)
df_Indian4_scaled_pca[:5]
# Out:
# array([[-1.86347876, -1.81494589, -0.19292422, -0.45499639,  0.67734606],
#        [-1.36643311, -1.91482691, -0.52975333,  0.27188783,  0.45616972],
#        [-0.41751032, -1.43690707,  1.84830105, -0.19813888,  0.30434236],
#        [ 0.3158646 , -1.62072668,  1.71359815,  0.30751746, -0.13547287],
#        [ 2.38140856, -1.85046665,  0.10683594, -0.53495271,  0.38531163]])

# %%
def pca_plot(pca, df, x_axis=0, y_axis=1, scale=1):
    plt.scatter(pca.components_[x_axis]*scale, pca.components_[y_axis]*scale, color='black')
    for x,y,name in zip(pca.components_[x_axis]*scale, pca.components_[y_axis]*scale, df.columns):
        plt.text(x, y+0.02, name, color='blue')
        plt.annotate('', (x,y), (0,0), arrowprops=dict(arrowstyle='->', color='red'))
    plt.scatter(0, 0, c='red')
    plt.xlabel(f'PCA{x_axis+1}')
    plt.ylabel(f'PCA{y_axis+1}')
    plt.show()

pca_plot(pca, df_Indian1)

# %% [markdown]
# # 2. EV sales by Makers 2015-2024

# %%
df01=pd.read_csv('Final Datasets/ev_sales_by_makers_and_cat_15-24.csv')

# %%
# Glimpse of data
print("Columns in the dataset:\n", df01.columns)
print("\nFirst few rows of the dataset:")
df01.head()
# Out:
# Columns in the dataset:
#  Index(['Cat', 'Maker', '2015', '2016', '2017', '2018', '2019', '2020', '2021',
#        '2022', '2023', '2024'],
#       dtype='object')
#
# First few rows of the dataset:
#   Cat                          Maker  2015  2016  2017  2018  2019  2020  \
# 0  3W      VOLVO GROUP INDIA PVT LTD     0     0    31    12     0     0
# 1  3W         3EV INDUSTRIES PVT LTD     0     0     0     0     0     0
# 2  2W         3GB TECHNOLOGY PVT LTD     0     0     0     1     0     0
# 3  3W         3GB TECHNOLOGY PVT LTD     0     1     1     0     0     0
# 4  3W  3S INDUSTRIES PRIVATE LIMITED     0     0     0     0    48    66
#
#    2021  2022  2023  2024
# 0     0     0     0     0
# 1   112   390   545    51
# 2     0     0     0     0
# 3     0     0     0     0
# 4    43    68   266   578

# %%
df01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1386 entries, 0 to 1385
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Cat     1386 non-null   object
#  1   Maker   1386 non-null   object
#  2   2015    1386 non-null   int64
#  3   2016    1386 non-null   int64
#  4   2017    1386 non-null   int64
#  5   2018    1386 non-null   int64
#  6   2019    1386 non-null   int64
#  7   2020    1386 non-null   int64
#  8   2021    1386 non-null   int64
#  9   2022    1386 non-null   int64
#  10  2023    1386 non-null   int64
#  11  2024    1386 non-null   int64
# dtypes: int64(10), object(2)
# memory usage: 130.1+ KB

# %%
df01.isna().sum()
# Out:
# Cat      0
# Maker    0
# 2015     0
# 2016     0
# 2017     0
# 2018     0
# 2019     0
# 2020     0
# 2021     0
# 2022     0
# 2023     0
# 2024     0
# dtype: int64

# %%
# Unique values of each columns
for col in df01.columns:
    unique_values=df01[col].unique()
    print(f"Unique values in column '{col}': {unique_values}\n")
# Out:
# Unique values in column 'Cat': ['3W' '2W' 'LMV' 'MMV']
#
# Unique values in column 'Maker': ['VOLVO GROUP INDIA PVT LTD' '3EV INDUSTRIES PVT LTD'
#  '3GB TECHNOLOGY PVT LTD' ... 'ZHONGHUALONG (IMPORTER: POWORO PVT LTD)'
#  'ZHONGXING (IMPORTER:GREENO AUTOMOBILE)' 'ZOHAN TRADERS AND BIG METRO']
#
# Unique values in column '2015': [   0    6    1   31   35  161   37  669    2    4   16   10  178   44
#     3   15   33  254   63   19   92  134  119   26   13   29    8   39
#     5  877   23  462    9   51  110 1708   40   56   38  140    7  227
#    17  326  165   22  107  780]
#
# Unique values in column '2016': [    0     1     2     8     3    39    32     6    80    15    10     5
#    397  1299    99    78    58  1321    57   147    43    24     9   311
#    492    46   157   136     7  1573    14    27     4   763   282    55
#    361   177   195    73    19    97   627    37    61    22   246    94
#     34    54    81   152    31   248    95    36   137    48    12  2005
#    250   190   133   400   441   210   131  3089    84   626   982    35
#    344   306    11   681   125    29    42   891   408   389   340 13401
#     66   101   212  1203   181    13    82   469    23   301    41   252
#     33   287    17    64  1493   171   299    49   846    77  3348  1665]
#
# Unique values in column '2017': [   31     0     1     2    72   100     8    33    94   471    21     4
#     17   187   239     7    69   114    44    25    93     5   131   195
#     29  1023   190   219    14    85    49    71    53    43    86    83
#    155    30    13  1501   271    18   608   321    62   536  1744   160
#    132   158    57    60     3   567   274    12  2205   129    50   777
#    130    39    26   919    11    15   627     6  1928   200   185    48
#     47   816   207    55   348    36     9   650   175   146   178   170
#    127    16    67   145   164    42   162    74   229    19   253    87
#    120   918   688   456  2652    88    23    37   442    79    20   429
#    352   383   880   678    10   168   421    38   184   420   169   408
#    386  2227    28  1196   147   242   443    51   499    35  1695   599
#    516   224  2889   369    76   336   331  1079   241   382 15094   581
#     77    22    40   309   409  1532   272    63   633   285   203   344
#    109   138   427   325   893  1825    58   357   135   791   266   211
#    282    59  1466  7434   605]
#
# Unique values in column '2018': [   12     0     1    56   625     2   280    85    75     4   179     6
#    240     3   176    15   763    41    69   505     5   182    78   153
#    214   331    64    21    16     7    24     9   660    31   492    11
#    336   206   216    54    37   191   132   113    20   283    87   295
#    160  2044   426   713    10    44    17   928  3005   195    19   395
#    854   397    46   330   192  3404    18   213   126    22    55   142
#    473   115    61    58   147    48  1184  2606   128   181    49   200
#     30   457  1626   117   565   506    59   277   241   246   140     8
#    570   220   131    98   251    77   297   616  5785    47    39    62
#    257   155  1216  1168   676   256  2921   157   779    26   174   471
#    238    52    96   205  1299   177  1374    68    13   287    14   394
#    125   348   144   666   165   487    66    45  2250  2033   431  4150
#    974    35   461   107   148  2513   102   291    86    34    29   573
#    361   568   468  8452  1701   145    27  1929  1687   560   138   210
#    219   503    23  1013    90   133   129   135   197    84   270   328
#     79   209  3226   354   233    40    32    50    63    92   582    33
#    175   575    28   770   285   380   900   141   185   700   111  2704
#   2850   919    71   356   260   581  1515   657   258  1996   329  2381
#     74   151    25 10816   789]
#
# Unique values in column '2019': [    0    48     3    42   438    28   452    41     6    10    13     1
#    315     8   296     2  1737   177    79    53    20   427  1196   118
#    287   190   267   276   251    99   308   393  2291     5   492   510
#    139   329   571   717   342   145     7    21   211    94   122  2312
#    565   708    16     4   123   687  4215    84   121    80    24   429
#     11   149  1031   222   119    12   896   106   163  3954    96    45
#    355    72   271  1150    58   147    23   181   270  2407   101   160
#    143    67   111    15   688    68  2257   195     9   472    93   693
#    262    51  1628   182   146    18   543    89    19   201   383   105
#    231   664 11155    33    85   192   131   108  1855   856   238   616
#    233    52  2314    74   414   633   248   362   184    37    46    34
#    208    26    40    55   250   657    38  1233  1463    43   266   419
#    127   307   302    35   714    65   210  1614    17  1988   537    32
#   6725  1786   499   167    54    87  2265    56   132   232    91    30
#    648   732   370   161    31   158   468   130 11850  1610    83    29
#    388  1576   312   269   234   246   286   285    44   504  2606    14
#     77   140   135    50   112   480    88   377    59  5080   243   188
#    950    61   209    69   794    97    63  1354   447    25   320   913
#    162   391   361   345   444    82    27   141  3545  3303  1103   448
#    368   656   313  2125   788   197   103  3217   306    39  1971   183
#    290   129 13213  1621]
#
# Unique values in column '2020': [   0   66    1  195   14  256    3    4   61  111    2   75   15 1180
#   308   30   22   25  656 4522  153   23  122   51   83  119  191  110
#    41  185  825    7 3052  176   12  438  204  124  328  517  366   92
#  1243   19   70   31  178  567   77 2155   50  460  413    9   17   99
#   263    6 2741   56   86   48   26  292    5   11   29   40  387   62
#   114 1100   16  140 2541   27  169  132  259  243   20   53    8   60
#    33   10 1324  131   55   63  274  318 2405   28   81  238  787   94
#  1476  100   38   36  129   21   79   73  593 8247  177   37  689  470
#   206  106 1260  249  660   95   42   43  454   32   89   57   39   96
#    78  357   72  607   13  669  304   47  220  207  377   54  194  692
#   881  248 4564  419 3219   35  103  162  772 1754  146  148  316  179
#   295   64 5754  672  345  933  199  115  156  138   59  255 1354  720
#   229   44 2098   52   87  275 4153  341   49  452  433  170  158  854
#   393  891  113  311  257   18  216  157  116  161 2717   24 2631 1986
#   869   82  233  289 1776  291  152 3083  212  858   74   34   68   88
#  9543 1281]
#
# Unique values in column '2021': [    0   112    43     5   256    20   677    17     6   202    10   207
#      1    34    53    65     8  2370   381   144     2    29    64    63
#    113   981 12470   315    11    79   111    96   221   418   203    24
#     31   373  1276    35     4 15930   132   893   431   326   139   957
#     13   470    39     7  4633    42    86   237  4758    91  5022   179
#     21   456   227  1708    26   213     9  6672   133    22   118    62
#     28   586    92  1125    55   285   345     3   755    30   141  5361
#     33   416   428   121   448    74    19   280   154    36    14    40
#     18   229   402   108  3070   148    75   119   134   519   214    15
#    447  2491   392   743   518  1409  1546   129   505  3058 46260   151
#    528   441  1091    69  1046   399   159   165   350    78    50  3075
#     67    27   180   176   224    49    84  1967   601   115    83   888
#     73   190    76  1214   835   840   136   391  1175   530    37    25
#    314   301   876   511   305   787    38   105  1804   289  3860  6711
#     82   396  1842  2384    94  3447    68   288   354   602    12    16
#    265   290   760    81   168 30659   240  1448   795   317    32  8541
#    777   162    66    47   160   181  2247   206    48   457 11044    45
#     54  3397    41  4704   408    60   415    61  7098   565    46    23
#    130   281   645  1318  2236   520    44  1877   481    77   603   434
#    356    58 10033   253  3404  3895   943   193  5258   311   940   499
#     72   778  3988   226    59  3924   329  1243   100 15793   931]
#
# Unique values in column '2022': [     0    390     68      3    433     93   1451      8    516     10
#     309     13    608    168    129    226    186      1     33     14
#    5884   1626    699     67      9     30     39     92   1159   1497
#   79857   2390      6     21     75      2     86    399    379    564
#      41    344   2782     61  51808    456   2864    943    115    485
#      64   1480     40    760    132    288  25318    195    105    333
#   13130    254   6447    141     12   1983      7   1591   1028    307
#      52     45    163    484   4514   3702    453     34    394     11
#   13091    426    406    223     36    827    571     24     46   3225
#     102     83    243    720      4   1334    104    303  13987    142
#     744    610    421   1381     47    728     29     49     20     82
#       5    509    735    367   6263    188     43    179    647     15
#      57    298    162    127   1056    401    177    395    268     31
#      23   4151   2048    864    644     25   1054   5343     65   2154
#     410     69    175    905    117   2538  97828    182    449   1162
#     297   2599    217   4397    848    306    619     16   1114     98
#     627     32   6947    636    224    396    155    496   9553     66
#     680     37    292    107    263    110    136   1433    130    321
#    3712    215   2085   2704    316    101   3487    684    338   1317
#      18     85   2350   4646   1523    185    114    477     17   2205
#      50   2865    469     80  13558  15931    133    173    854     84
#      60     94   3215   3430    362  10487     26    825   1723     28
#     542   1331    289     19    569     77    167   1563    335    313
#     160     63   8913 103620 109398   2930   1167   2785    146    172
#   15099   2165    431   1120    706   7431    120  14953     35    125
#     170     71    281    119  14910   1564    200    143    518    189
#   19314   1133    241    353   1310     55    415    213    853     91
#     181   1554    264   2003     38   6308     90     48   3734    131
#    1222   1746    340   2217    211   1006   1038    244    227   1240
#    1621  30610    234     42   7876     79   5915   1382    319   1355
#     391     58  47182    476   2724   1978    191   1671  10246    156
#      59     72   5969    398   2135    193    248    407    140    446
#     314  29793   1561    382]
#
# Unique values in column '2023': [     0    545    266      2    563    279   1309    797     34    918
#      18     12    598      4    689      1    179    129     61    138
#     190     39      5     59  10743      8   2517   2512      7     37
#      13     14    162    145   1910   1574  42903     51     74     87
#     778    725   1077    590   3958     86      6    294 104735    760
#    5502    127    105   2335    143    578    103     11   2632     10
#     784    112     28   1363     40  71940   4574    947    146    274
#    4139    271   3005    382   7902     33  11454    106   2682   1814
#     673     72     65    207   3565   3695     31   2012     50      3
#     109    874  14877    501    571    290   4851    135    930   2749
#      96     32   5925    283    122    311   1563   2466     29    604
#   25071   1026     26    934    751   1296    240     17    595   1245
#      89    526    125     43   1200    230    470  11080    188    472
#     587     55    116     80   2595     44    166    540     83   2379
#     614    218    900    546    119     57     16   1430   5514    383
#    2950    711    128    462     71   1494   3040    136   3411  24045
#      42    442    345     46    221    872     64  29964  11142    624
#    1367     84   3741    209    785  12840     62   1011     91   1606
#     276   2035     19   2154  11165    113      9    165    163    600
#     950     38    208    454     20     22     85    799   2617    740
#      52    212    156    479    139    288   1846    197    224    339
#     405   8478    438   7779   4648     58     81   4173    904    335
#     569   2469    244     15    358   6203   7288   1644    186   1097
#    3637    153   2571    564     60  37942   4505   4949     56  11733
#     299    433   1810     27    147    322    193    195   9520     97
#   15962    102     70     77   2965   4925    667     45   1253    326
#     439    164   2650    473    210    157  15816  31616 267355   3304
#    1203   3579     67   1435    351     41   3246    572     21   1950
#   21079    214    101    206    500   7191     23    338   2371    124
#      99    114    575    152   1176    609   1080    237   6976    822
#     496     92     68    629    126  29321   5788     36    175    677
#     204   2831     54    911     49    787    617    431    110    120
#     307   4086    645   2726    359     24  10078     47    187    132
#    4770   2121   2248    767   2077    570    286    142   1198    134
#    2020    434   2845   1766    275  21420  38580    346   8810     48
#    7271   1273   1743   1589   1361    296     30    987 166580   1505
#    3848   2438    256    137    211   3580  13572    272    355   7832
#     171    574     25   3319   4807    181    831    123   6910    426
#     182     35    389    278    316  40794     82   2836    718   3563
#     131]
#
# Unique values in column '2024': [     0     51    578    355    146     66    164    674      2    312
#       4   1194     16     48    329      1    927    152    151      8
#      34    109   1048     20    131   6317   1804    939      6     14
#       7     55    327   1060     80    857     22      3     39     53
#      30    395    685    777     29     76   1925    126    828  58547
#     408   3938    308   1593    100    524   1951    429     25    663
#     515  73698  16461    575     99     21    112    159   1836   1481
#     402    137   3545     10  10711     81   1398   1377   1040     24
#     591    326   1598   1853     41   1401    357    394     93   6654
#      37    106    380    190    154    301    425      5   2871     72
#      73    120   1246    287     83     26    234  11832     43    403
#      23     27    444    495    479     86    127    816     44    165
#     170    202     40    934     82    259   6782    184    237     13
#     599    331   2104     60     18     36    123   1318    470     90
#     496     58    281    648   2850    508     19    163   1053    277
#     155     32    115    952     11   2043  18424    172    169    176
#     198    168    424     68   2211  19479    321    580   2783    340
#    7423    255    562     17    757    241   1399    272    668   6278
#     108     61    770    101    121    687    348   1383    678    102
#      52    189     12      9    211     42     33   1242    105     87
#     364    522   5591   7515   1756     77   1889    192    748     91
#    1100     15    218     45    264   2661   3785    194     50     88
#     657   1852     35    230   1373    401   1331   4305     57  34331
#     430    590    766    195   1280     65    316   7229   7092    143
#      31    210     38   2297   2796    153     54    502     67     28
#     138   2110    150    217     47   4387   3893 211273   1461    768
#     550    188   4592    174     84     56   1822    265    514    916
#   12869    360    249     89     94     79    220   3143    462   3178
#     276    564    452    990    530    110    759   4650    223    162
#    1134    180    260    246    107    405  16408   5074     97    386
#    2169    700   1568    145     98   3224   1240    568    322     63
#    5687    244    232   2228    941   1021    620   1133    315    207
#     538     71   1390    219   1948   3076    490  35830   4959   3924
#    3139    809    931    422    227    460  98516    449   2002   1760
#      69    125    874   2132   8121    208   4577     59    204   1402
#    3091    142    704    317    847   7166     64    282    157    167
#      96  23892   2626    612   3578     74]

# %%
# Sum sales across all years for each maker
df01['Total_Sales'] = df01.iloc[:, 2:].sum(axis=1)

# %%
df01.head()
# Out:
#   Cat                          Maker  2015  2016  2017  2018  2019  2020  \
# 0  3W      VOLVO GROUP INDIA PVT LTD     0     0    31    12     0     0
# 1  3W         3EV INDUSTRIES PVT LTD     0     0     0     0     0     0
# 2  2W         3GB TECHNOLOGY PVT LTD     0     0     0     1     0     0
# 3  3W         3GB TECHNOLOGY PVT LTD     0     1     1     0     0     0
# 4  3W  3S INDUSTRIES PRIVATE LIMITED     0     0     0     0    48    66
#
#    2021  2022  2023  2024  Total_Sales
# 0     0     0     0     0           43
# 1   112   390   545    51         1098
# 2     0     0     0     0            1
# 3     0     0     0     0            2
# 4    43    68   266   578         1069

# %%
df01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1386 entries, 0 to 1385
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Cat          1386 non-null   object
#  1   Maker        1386 non-null   object
#  2   2015         1386 non-null   int64
#  3   2016         1386 non-null   int64
#  4   2017         1386 non-null   int64
#  5   2018         1386 non-null   int64
#  6   2019         1386 non-null   int64
#  7   2020         1386 non-null   int64
#  8   2021         1386 non-null   int64
#  9   2022         1386 non-null   int64
#  10  2023         1386 non-null   int64
#  11  2024         1386 non-null   int64
#  12  Total_Sales  1386 non-null   int64
# dtypes: int64(11), object(2)
# memory usage: 140.9+ KB

# %%
# Find the maker with the highest and lowest sales for each category
highest_sales = df01.groupby('Cat').apply(lambda x: x.loc[x['Total_Sales'].idxmax()])
lowest_sales = df01.groupby('Cat').apply(lambda x: x.loc[x['Total_Sales'].idxmin()])

# Display results
print("Makers with the highest sales in each category:")
print(highest_sales[['Cat', 'Maker', 'Total_Sales']])
# Out:
# Makers with the highest sales in each category:
#      Cat                                 Maker  Total_Sales
# Cat
# 2W    2W     OLA ELECTRIC TECHNOLOGIES PVT LTD       588266
# 3W    3W                   YC ELECTRIC VEHICLE       152944
# LMV  LMV  TATA PASSENGER ELECTRIC MOBILITY LTD        74410
# MMV  MMV                       TATA MOTORS LTD          702
# C:\Users\hp\AppData\Local\Temp\ipykernel_1600\2641482054.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   highest_sales = df01.groupby('Cat').apply(lambda x: x.loc[x['Total_Sales'].idxmax()])
# C:\Users\hp\AppData\Local\Temp\ipykernel_1600\2641482054.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   lowest_sales = df01.groupby('Cat').apply(lambda x: x.loc[x['Total_Sales'].idxmin()])

# %%
# Identify all columns that are numeric years
year_columns = [col for col in df01.columns if col.isdigit()]

# Reshape the data from wide to long format, only using year columns
df_long = pd.melt(df01, id_vars=['Cat', 'Maker'], 
                  value_vars=year_columns, var_name='Year', value_name='Sales')

# Ensure 'Year' is treated as a numeric column
df_long['Year'] = pd.to_numeric(df_long['Year'])

# %%
# Find the maker with the highest sales for each year and category
highest_sales_year_cat = df_long.groupby(['Year', 'Cat']).apply(lambda x: x.loc[x['Sales'].idxmax()]).reset_index(drop=True)

# Display results
print("Year-wise and category-wise makers with the highest sales:")
print(highest_sales_year_cat[['Year', 'Cat', 'Maker', 'Sales']])
# Out:
# Year-wise and category-wise makers with the highest sales:
#     Year  Cat                                 Maker   Sales
# 0   2015   2W         HERO ELECTRIC VEHICLE PVT LTD     254
# 1   2015   3W                                OTHERS    1708
# 2   2015  LMV    MAHINDRA ELECTRIC MOBILITY LIMITED     462
# 3   2015  MMV                      DIVYA INDUSTRIES       1
# 4   2016   2W         HERO ELECTRIC VEHICLE PVT LTD     246
# 5   2016   3W                                OTHERS   13401
# 6   2016  LMV           MAHINDRA & MAHINDRA LIMITED     344
# 7   2016  MMV                    KION INDIA PVT LTD       2
# 8   2017   2W                                OTHERS     382
# 9   2017   3W                                OTHERS   15094
# 10  2017  LMV                                OTHERS     581
# 11  2017  MMV                       TATA MOTORS LTD       4
# 12  2018   2W              OKINAWA AUTOTECH PVT LTD    8452
# 13  2018   3W                   YC ELECTRIC VEHICLE   10816
# 14  2018  LMV           MAHINDRA & MAHINDRA LIMITED     974
# 15  2018  MMV                       TATA MOTORS LTD       4
# 16  2019   2W              OKINAWA AUTOTECH PVT LTD   11850
# 17  2019   3W                   YC ELECTRIC VEHICLE   13213
# 18  2019  LMV           MAHINDRA & MAHINDRA LIMITED     687
# 19  2019  MMV                       TATA MOTORS LTD     119
# 20  2020   2W       HERO ELECTRIC VEHICLES PVT. LTD    8247
# 21  2020   3W                   YC ELECTRIC VEHICLE    9543
# 22  2020  LMV                       TATA MOTORS LTD    2717
# 23  2020  MMV                       TATA MOTORS LTD      26
# 24  2021   2W       HERO ELECTRIC VEHICLES PVT. LTD   46260
# 25  2021   3W                   YC ELECTRIC VEHICLE   15793
# 26  2021  LMV                       TATA MOTORS LTD   10033
# 27  2021  MMV                       TATA MOTORS LTD     253
# 28  2022   2W     OLA ELECTRIC TECHNOLOGIES PVT LTD  109398
# 29  2022   3W                   YC ELECTRIC VEHICLE   29793
# 30  2022  LMV    TATA MOTORS PASSENGER VEHICLES LTD   30610
# 31  2022  MMV                       TATA MOTORS LTD      15
# 32  2023   2W     OLA ELECTRIC TECHNOLOGIES PVT LTD  267355
# 33  2023   3W                   YC ELECTRIC VEHICLE   40794
# 34  2023  LMV  TATA PASSENGER ELECTRIC MOBILITY LTD   38580
# 35  2023  MMV                       TATA MOTORS LTD     275
# 36  2024   2W     OLA ELECTRIC TECHNOLOGIES PVT LTD  211273
# 37  2024   3W       MAHINDRA LAST MILE MOBILITY LTD   34331
# 38  2024  LMV  TATA PASSENGER ELECTRIC MOBILITY LTD   35830
# 39  2024  MMV                     ALL TERRAIN CRANE      20
# C:\Users\hp\AppData\Local\Temp\ipykernel_1600\3575668353.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   highest_sales_year_cat = df_long.groupby(['Year', 'Cat']).apply(lambda x: x.loc[x['Sales'].idxmax()]).reset_index(drop=True)

# %%
# Plot for the highest sales
plt.figure(figsize=(14, 8))
sns.barplot(data=highest_sales_year_cat, x='Year', y='Sales', hue='Cat', dodge=True)
plt.title('Year-wise and Category-wise Highest Sales', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Sales', fontsize=14)
plt.xticks(rotation=45)
plt.legend(title='Category')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
df_long1 = pd.melt(df01, id_vars=['Cat'], var_name='Year', value_name='Sales')

# Group by category and sum up the sales
category_sales1 = df_long.groupby('Cat')['Sales'].sum().reset_index()

# Sort by total sales in descending order for better visualization
category_sales1 = category_sales1.sort_values(by='Sales', ascending=False)

print(category_sales1)
# Out:
#    Cat    Sales
# 0   2W  2279448
# 1   3W  1934263
# 2  LMV   206388
# 3  MMV      804

# %%
# Set up the figure
plt.figure(figsize=(10, 10))

# Create a pie chart
plt.pie(
    category_sales1['Sales'], 
    labels=category_sales1['Cat'], 
    autopct='%1.3f%%', 
    colors=plt.get_cmap('Set2').colors
)

# Set plot title
plt.title('Total Vehicles Sold by Category from 2015-2024', fontsize=16)

# Show the plot
plt.show()

# %% [markdown]
# # 3. EV Makers by Place

# %%
# Loading the dataset
df02 = pd.read_csv('EV Maker by Place.csv')

# %%
df02.head()
# Out:
#             EV Maker        Place        State
# 0        Tata Motors         Pune  Maharashtra
# 1  Mahindra Electric    Bengaluru    Karnataka
# 2       Ather Energy    Bengaluru    Karnataka
# 3      Hero Electric    New Delhi        Delhi
# 4       Ola Electric  Krishnagiri   Tamil Nadu

# %%
df02.shape
# Out:
# (62, 3)

# %%
df02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   EV Maker  62 non-null     object
#  1   Place     62 non-null     object
#  2   State     62 non-null     object
# dtypes: object(3)
# memory usage: 1.6+ KB

# %%
df02['EV Maker'].unique()
# Out:
# array(['Tata Motors', 'Mahindra Electric', 'Ather Energy',
#        'Hero Electric', 'Ola Electric', 'Ashok Leyland',
#        'TVS Motor Company', 'Bajaj Auto', 'MG Motor India',
#        'Hyundai Motor India', 'Revolt Motors', 'Ampere Vehicles',
#        'Okinawa Autotech', 'Kinetic Green Energy', 'BYD India',
#        'JBM Auto', 'Piaggio Vehicles', 'Hero MotoCorp',
#        'Etrio Automobiles', 'Triton Electric', 'Simple Energy',
#        'Minda Industries', 'Exide Industries', 'Greaves Cotton',
#        'Maruti Suzuki India', 'Renault India', 'Citroën India',
#        'Audi India', 'Mercedes-Benz India', 'Kia Motors India',
#        'Volvo Eicher', 'JSW Energy', 'Olectra Greentech', 'Force Motors',
#        'TVS Electronics', 'Royal Enfield', 'Bharat Forge',
#        'Hindustan Motors', 'Atul Auto', 'SML Isuzu', 'Mahindra Reva',
#        'Ajanta Manufacturing', 'Tata Power', 'Ashok Leyland (EV Bus)',
#        'HOP Electric Mobility', 'Omega Seiki Mobility', 'Bajaj Auto (EV)',
#        'Tata AutoComp Systems', 'Bosch India', 'Lohia Auto Industries',
#        'Saera Electric Auto', 'Jezza Motors', 'Altigreen Propulsion Labs',
#        'Terra Motors India', 'Gayam Motor Works',
#        'Kinetic Green (3-Wheeler)', 'Greaves Electric Mobility',
#        'YC Electric Vehicle', 'Dilli Electric Auto Pvt Ltd',
#        'Electrotherm India', 'Euler Motors'], dtype=object)

# %%
df02['Place'].unique()
# Out:
# array(['Pune', 'Bengaluru', 'New Delhi', 'Krishnagiri', 'Chennai',
#        'Hosur', 'Halol', 'Gurgaon', 'Coimbatore', 'Bhiwadi',
#        'Sriperumbudur', 'Faridabad', 'Baramati', 'Dharuhera', 'Hyderabad',
#        'Bhuj', 'Kolkata', 'Mumbai', 'Manesar', 'Thiruvallur',
#        'Aurangabad', 'Chakan', 'Anantapur', 'Pithampur', 'Uttarpara',
#        'Rajkot', 'Ropar', 'Morbi', 'Alwar', 'Jaipur', 'Akurdi',
#        'Kashipur', 'Gurugram', 'Ahmednagar', 'Delhi', 'Ahmedabad'],
#       dtype=object)

# %%
df02['State'].unique()
# Out:
# array(['Maharashtra', 'Karnataka', 'Delhi', 'Tamil Nadu', 'Gujarat',
#        'Haryana', 'Rajasthan', 'Telangana', 'West Bengal',
#        'Andhra Pradesh', 'Madhya Pradesh', 'Punjab', 'Uttarakhand'],
#       dtype=object)

# %%
for i in df02.columns:
    print(f'{i}:\n{df02[i].unique()}')
# Out:
# EV Maker:
# ['Tata Motors' 'Mahindra Electric' 'Ather Energy' 'Hero Electric'
#  'Ola Electric' 'Ashok Leyland' 'TVS Motor Company' 'Bajaj Auto'
#  'MG Motor India' 'Hyundai Motor India' 'Revolt Motors' 'Ampere Vehicles'
#  'Okinawa Autotech' 'Kinetic Green Energy' 'BYD India' 'JBM Auto'
#  'Piaggio Vehicles' 'Hero MotoCorp' 'Etrio Automobiles' 'Triton Electric'
#  'Simple Energy' 'Minda Industries' 'Exide Industries' 'Greaves Cotton'
#  'Maruti Suzuki India' 'Renault India' 'Citroën India' 'Audi India'
#  'Mercedes-Benz India' 'Kia Motors India' 'Volvo Eicher' 'JSW Energy'
#  'Olectra Greentech' 'Force Motors' 'TVS Electronics' 'Royal Enfield'
#  'Bharat Forge' 'Hindustan Motors' 'Atul Auto' 'SML Isuzu' 'Mahindra Reva'
#  'Ajanta Manufacturing' 'Tata Power' 'Ashok Leyland (EV Bus)'
#  'HOP Electric Mobility' 'Omega Seiki Mobility' 'Bajaj Auto (EV)'
#  'Tata AutoComp Systems' 'Bosch India' 'Lohia Auto Industries'
#  'Saera Electric Auto' 'Jezza Motors' 'Altigreen Propulsion Labs'
#  'Terra Motors India' 'Gayam Motor Works' 'Kinetic Green (3-Wheeler)'
#  'Greaves Electric Mobility' 'YC Electric Vehicle'
#  'Dilli Electric Auto Pvt Ltd' 'Electrotherm India' 'Euler Motors']
# Place:
# ['Pune' 'Bengaluru' 'New Delhi' 'Krishnagiri' 'Chennai' 'Hosur' 'Halol'
#  'Gurgaon' 'Coimbatore' 'Bhiwadi' 'Sriperumbudur' 'Faridabad' 'Baramati'
#  'Dharuhera' 'Hyderabad' 'Bhuj' 'Kolkata' 'Mumbai' 'Manesar' 'Thiruvallur'
#  'Aurangabad' 'Chakan' 'Anantapur' 'Pithampur' 'Uttarpara' 'Rajkot'
#  'Ropar' 'Morbi' 'Alwar' 'Jaipur' 'Akurdi' 'Kashipur' 'Gurugram'
#  'Ahmednagar' 'Delhi' 'Ahmedabad']
# State:
# ['Maharashtra' 'Karnataka' 'Delhi' 'Tamil Nadu' 'Gujarat' 'Haryana'
#  'Rajasthan' 'Telangana' 'West Bengal' 'Andhra Pradesh' 'Madhya Pradesh'
#  'Punjab' 'Uttarakhand']

# %%
manufacturer_counts = df02['EV Maker'].value_counts()

# Plotting the pie chart
plt.figure(figsize=(19, 20))
plt.pie(manufacturer_counts, labels=manufacturer_counts.index, 
        autopct='%1.2f%%', startangle=140)
plt.title('Market Share of EV Manufacturers')
plt.savefig('Pie-Market Share of EV Manufacturers.png')
plt.show()

# %%
# Grouping by State and aggregating EV Maker names
state_ev_makers = df02.groupby('State')['EV Maker'].apply(lambda x: ', '.join(x.unique())).reset_index()

# Renaming columns for clarity
state_ev_makers.columns = ['State', 'EV Maker Names']

# Adding a column for the number of distinct EV makers
state_ev_makers['Number of EV Makers'] = state_ev_makers['EV Maker Names'].apply(lambda x: len(x.split(', ')))

state_ev_makers
# Out:
#              State                                     EV Maker Names  \
# 0   Andhra Pradesh                                   Kia Motors India
# 1            Delhi  Hero Electric, YC Electric Vehicle, Dilli Elec...
# 2          Gujarat  MG Motor India, Triton Electric, Atul Auto, Aj...
# 3          Haryana  Revolt Motors, JBM Auto, Hero MotoCorp, Maruti...
# 4        Karnataka  Mahindra Electric, Ather Energy, Simple Energy...
# 5   Madhya Pradesh                                       Volvo Eicher
# 6      Maharashtra  Tata Motors, Bajaj Auto, Kinetic Green Energy,...
# 7           Punjab                                          SML Isuzu
# 8        Rajasthan  Okinawa Autotech, Ashok Leyland (EV Bus), HOP ...
# 9       Tamil Nadu  Ola Electric, Ashok Leyland, TVS Motor Company...
# 10       Telangana  Etrio Automobiles, Olectra Greentech, Gayam Mo...
# 11     Uttarakhand                              Lohia Auto Industries
# 12     West Bengal   Exide Industries, Hindustan Motors, Jezza Motors
#
#     Number of EV Makers
# 0                     1
# 1                     4
# 2                     5
# 3                     6
# 4                     6
# 5                     1
# 6                    15
# 7                     1
# 8                     4
# 9                    11
# 10                    3
# 11                    1
# 12                    3

# %%
'''# Grouping by State and getting distinct manufacturers for each state
state_ev_makers = df02.groupby('State')['EV Maker'].unique().reset_index()

# Adding a column for the count of distinct manufacturers
state_ev_makers['Number of EV Makers'] = state_ev_makers['EV Maker'].apply(len)

print(state_ev_makers)
'''

# %%
# Display state-wise EV makers along with their numbers
for index, row in state_ev_makers.iterrows():
    print(f"State: {row['State']}")
    print(f"Number of EV Makers: {row['Number of EV Makers']}")
    print(f"EV Maker Names: {row['EV Maker Names']}")
    print("-" * 40)
# Out:
# State: Andhra Pradesh
# Number of EV Makers: 1
# EV Maker Names: Kia Motors India
# ----------------------------------------
# State: Delhi
# Number of EV Makers: 4
# EV Maker Names: Hero Electric, YC Electric Vehicle, Dilli Electric Auto Pvt Ltd, Euler Motors
# ----------------------------------------
# State: Gujarat
# Number of EV Makers: 5
# EV Maker Names: MG Motor India, Triton Electric, Atul Auto, Ajanta Manufacturing, Electrotherm India
# ----------------------------------------
# State: Haryana
# Number of EV Makers: 6
# EV Maker Names: Revolt Motors, JBM Auto, Hero MotoCorp, Maruti Suzuki India, Omega Seiki Mobility, Terra Motors India
# ----------------------------------------
# State: Karnataka
# Number of EV Makers: 6
# EV Maker Names: Mahindra Electric, Ather Energy, Simple Energy, Mahindra Reva, Bosch India, Altigreen Propulsion Labs
# ----------------------------------------
# State: Madhya Pradesh
# Number of EV Makers: 1
# EV Maker Names: Volvo Eicher
# ----------------------------------------
# State: Maharashtra
# Number of EV Makers: 15
# EV Maker Names: Tata Motors, Bajaj Auto, Kinetic Green Energy, Piaggio Vehicles, Minda Industries, Greaves Cotton, Audi India, Mercedes-Benz India, JSW Energy, Force Motors, Bharat Forge, Tata Power, Bajaj Auto (EV), Tata AutoComp Systems, Kinetic Green (3-Wheeler)
# ----------------------------------------
# State: Punjab
# Number of EV Makers: 1
# EV Maker Names: SML Isuzu
# ----------------------------------------
# State: Rajasthan
# Number of EV Makers: 4
# EV Maker Names: Okinawa Autotech, Ashok Leyland (EV Bus), HOP Electric Mobility, Saera Electric Auto
# ----------------------------------------
# State: Tamil Nadu
# Number of EV Makers: 11
# EV Maker Names: Ola Electric, Ashok Leyland, TVS Motor Company, Hyundai Motor India, Ampere Vehicles, BYD India, Renault India, Citroën India, TVS Electronics, Royal Enfield, Greaves Electric Mobility
# ----------------------------------------
# State: Telangana
# Number of EV Makers: 3
# EV Maker Names: Etrio Automobiles, Olectra Greentech, Gayam Motor Works
# ----------------------------------------
# State: Uttarakhand
# Number of EV Makers: 1
# EV Maker Names: Lohia Auto Industries
# ----------------------------------------
# State: West Bengal
# Number of EV Makers: 3
# EV Maker Names: Exide Industries, Hindustan Motors, Jezza Motors
# ----------------------------------------

# %%
pivot_table = df02.pivot_table(index='State', columns='Place',
                             aggfunc='size',fill_value=0)

# Plotting the stacked bar chart
pivot_table.plot(kind='bar', stacked=True, figsize=(14, 8), colormap='tab20')
plt.title('Distribution of EV Manufacturers by City within Each State')
plt.xlabel('State')
plt.ylabel('Number of Manufacturers')
plt.legend(title='City', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
df02.head()
# Out:
#             EV Maker        Place        State
# 0        Tata Motors         Pune  Maharashtra
# 1  Mahindra Electric    Bengaluru    Karnataka
# 2       Ather Energy    Bengaluru    Karnataka
# 3      Hero Electric    New Delhi        Delhi
# 4       Ola Electric  Krishnagiri   Tamil Nadu

# %%
# Calculate market share
market_share = df02['EV Maker'].value_counts(normalize=True).reset_index()
market_share.columns = ['EV Maker', 'Market Share']
market_share['Market Share'] = market_share['Market Share'] * 100

# Count distinct EV Makers by state and city
distinct_makers_by_state = df02.groupby('State')['EV Maker'].nunique().reset_index()
distinct_makers_by_city = df02.groupby('Place')['EV Maker'].nunique().reset_index()

# Find the largest EV maker
largest_maker = df02['EV Maker'].value_counts().reset_index()
largest_maker.columns = ['EV Maker', 'Count']
largest_maker = largest_maker.iloc[0]  # Get the largest EV maker


# Visualize distinct EV Makers by city
plt.figure(figsize=(12, 6))
sns.barplot(x='Place', y='EV Maker', data=distinct_makers_by_city, palette='viridis')
plt.title('Distinct EV Makers by City')
plt.xlabel('City')
plt.ylabel('Number of Distinct EV Makers')
plt.xticks(rotation=45)
plt.show()

# Display largest EV Maker
print(f"Largest EV Maker: {largest_maker['EV Maker']} with {largest_maker['Count']} entries")
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_1600\4200857393.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Place', y='EV Maker', data=distinct_makers_by_city, palette='viridis')
# Largest EV Maker: Lohia Auto Industries with 2 entries
